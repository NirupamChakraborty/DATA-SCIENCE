# %% [markdown]
#  #### Tuples
#
#
# Introduction to Tuples
#
#
# Creating Tuples
#
#
# Accessing Tuple Elements
#
#
# Tuple Operations
#
#
# Immutable Nature of Tuples
#
#
# Tuple Methods
#
#
# Packing and Unpacking Tuples
#
#
# Nested Tuples
#
#
# Practical Examples and Common Errors
#
#
# Introduction to Tuples
#
#
# Explanation:
#
#
# Tuples are ordered collections of items that are immutable. They are similar to lists, but their immutability makes them different.

# %%
## creating a tuple
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))

# %%
# creating a list using a list class method
lst=list()
print(lst)
print(type(lst))
# Out:
# []
# <class 'list'>

# %%
# creating a tuple using a tuple class method
tup=tuple()
print(tup)
print(type(tup))
# Out:
# ()
# <class 'tuple'>

# %%
numbers_tuple = tuple([1, 2, 3, 4, 5])
numbers_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
numbers_list = list((1, 2, 3, 4, 5))
numbers_list
# Out:
# [1, 2, 3, 4, 5]

# %%
mixed_tuple=(1,"Hello World",3.14, True)
print(mixed_tuple)
# Out:
# (1, 'Hello World', 3.14, True)

# %%
print(numbers_tuple)
print(numbers_tuple[2])
print(numbers_tuple[-1])
# Out:
# (1, 2, 3, 4, 5)
# 3
# 5

# %%
numbers_tuple[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers_tuple[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
concatenation_tuple=numbers_tuple + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 1, 'Hello World', 3.14, True)

# %%
mixed_tuple * 3  # create element5s 3 times
# Out:
# (1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True)

# %%
## Immutable Nature Of Tuples
## Tuples are immutable, meaning their elements cannot be changed once assigned.

lst=[1,2,3,4,5]
print(lst)

lst[1]="Krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Krish', 3, 4, 5]

# %%
numbers_tuple[1]="Krish"
# tuples are immutable
# to change any element in a tuple you need to first convert tuple to list 
# and change and then convert list to tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 numbers_tuple[1]="Krish"
#       2 # tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
## Tuple Methods
print(numbers_tuple.count(1))
print(numbers_tuple.index(3))
# Out:
# 1
# 2

# %%
## Packing and Unpacking tuple
## packing
packed_tuple=1,"Hello",3.14
print(packed_tuple) #comma seperated value get converted to a tuple by deafault
# Out:
# (1, 'Hello', 3.14)

# %%
##unpacking a tuple
a,b,c=packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
## Unpacking with *
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested Tuple
## Nested List
lst=[[1,2,3,4],[6,7,8,9],[1,"Hello",3.14,"c"]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello",3.14,"c")]
lst[1][0:3]
# Out:
# [6, 7, 8]

# %%
nested_tuple = ((1, 2, 3), ("a", "b", "c"), (True, False))

## access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
## iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False

# %% [markdown]
# Conclusion
#
# Tuples are versatile and useful in many real-world scenarios where an immutable and ordered collection of items is required. They are commonly used in data structures, function arguments and return values, and as dictionary keys. Understanding how to leverage tuples effectively can improve the efficiency and readability of your Python code.
